# %%
"""
Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
"""

"""
1. Strip Plot
This is the one kind of scatter plot of categorical data

2. Swarm Plot
This is very much similar to stripplot but the only difference is that it does not allow overlapping of markers.
It causes jittering in the markers of the plot so that graph can easily be read without information loss as see

3. Bar Plot
A barplot is basically used to aggregate the categorical data according to some methods and by default it’s the mean. 
It can also be understood as a visualization of the group by action.

4. Count Plot
A countplot basically counts the categories and returns a count of their occurrences.

5. Box Plot
Box Plot is the visual representation of the depicting groups of numerical data through their quartiles. 
Boxplot is also used to detect the outlier in the data set.
"""

# %%
"""
Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
"timepoint" and y = "signal" for different events and regions.
Note: timepoint, signal, event, and region are columns in the fmri dataset.
"""
import seaborn as sb
import matplotlib.pyplot as plt

fmri   = sb.load_dataset('fmri')

uniqueEvents  = fmri['event'].unique()
uniqueRegions = fmri['region'].unique()

for e in uniqueEvents:
    for r in uniqueRegions:
        print(e, r)
        fmri_rest = fmri[(fmri['event'] == e) & (fmri['region'] == r)]
        print(fmri_rest)
    
        sb.lineplot(x="timepoint", y="signal", data = fmri_rest[['timepoint', 'signal']]).set(title = f"Event = {e}, Region = {r}")
        plt.show()
# Out:
# stim parietal
#     subject  timepoint event    region    signal
# 0       s13         18  stim  parietal -0.017552
# 1        s5         14  stim  parietal -0.080883
# 2       s12         18  stim  parietal -0.081033
# 3       s11         18  stim  parietal -0.046134
# 4       s10         18  stim  parietal -0.037970
# ..      ...        ...   ...       ...       ...
# 263      s2          0  stim  parietal -0.034407
# 264      s5          9  stim  parietal -0.074843
# 265      s0         13  stim  parietal -0.055264
# 266      s6         16  stim  parietal -0.039951
# 521      s0          0  stim  parietal -0.039327
#
# [266 rows x 5 columns]
# stim frontal
#     subject  timepoint event   region    signal
# 67       s0          0  stim  frontal -0.021452
# 170      s2          6  stim  frontal  0.101050
# 267     s10          4  stim  frontal  0.030044
# 268     s11          4  stim  frontal  0.075957
# 269      s3          0  stim  frontal  0.011056
# ..      ...        ...   ...      ...       ...
# 527      s8         18  stim  frontal -0.011114
# 528      s6         18  stim  frontal  0.046500
# 529      s5         18  stim  frontal -0.031013
# 530      s4         18  stim  frontal -0.063263
# 531      s7         18  stim  frontal -0.019634
#
# [266 rows x 5 columns]
# cue parietal
#      subject  timepoint event    region    signal
# 532       s3          4   cue  parietal  0.058219
# 533       s6          5   cue  parietal  0.038145
# 534       s7          5   cue  parietal -0.008158
# 535       s8          5   cue  parietal  0.047136
# 536       s9          5   cue  parietal  0.055847
# ...      ...        ...   ...       ...       ...
# 930       s7         16   cue  parietal -0.024589
# 931       s8          9   cue  parietal -0.039664
# 949       s6          9   cue  parietal -0.069248
# 967       s5          9   cue  parietal -0.056757
# 1063      s0          0   cue  parietal -0.006899
#
# [266 rows x 5 columns]
# cue frontal
#      subject  timepoint event   region    signal
# 566       s4         14   cue  frontal -0.026796
# 579       s5         14   cue  frontal -0.017213
# 596       s9          0   cue  frontal -0.008117
# 597       s9          6   cue  frontal  0.026864
# 598       s3         14   cue  frontal -0.030614
# ...      ...        ...   ...      ...       ...
# 1058      s1          8   cue  frontal -0.136059
# 1059      s0          8   cue  frontal  0.018165
# 1060     s13          7   cue  frontal -0.029130
# 1061     s12          7   cue  frontal -0.004939
# 1062     s11          7   cue  frontal -0.025367
#
# [266 rows x 5 columns]

# %%
"""
Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
'pclass', y = 'age' and y = 'fare'.
Note: pclass, age, and fare are columns in the titanic dataset.
"""
import seaborn as sb
import matplotlib.pyplot as plt

titanic = sb.load_dataset('titanic')
print(titanic, '\n')

sb.boxplot(x = 'pclass', y = 'age', data = titanic)
plt.show()

sb.boxplot(x = 'pclass', y = 'fare', data = titanic)
plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
"""
Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
parameter for the 'cut' column of the diamonds dataset.
"""
import seaborn as sb
import matplotlib.pyplot as plt

diamonds = sb.load_dataset('diamonds')
print(diamonds, '\n')

sb.histplot(data = diamonds, x = "price", hue = "cut", kde = True)
plt.show()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
"""
Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
of the iris dataset.
"""
import seaborn as sb
import matplotlib.pyplot as plt

iris = sb.load_dataset('iris')
print(iris, '\n')

sb.pairplot(iris, hue ='species')
plt.show()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
"""
Que 6: Use the "flights" dataset from seaborn to plot a heatmap.
"""
import seaborn as sb
import matplotlib.pyplot as plt

flights = sb.load_dataset('flights')
print(flights, '\n')

flights_pivot = flights.pivot("month", "year", "passengers")
print(flights_pivot, '\n')

sb.heatmap(data = flights_pivot)
plt.show()
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
#
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432
# /tmp/ipykernel_99/3878067891.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_pivot = flights.pivot("month", "year", "passengers")
